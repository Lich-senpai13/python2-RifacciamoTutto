# %%
import pandas as pd

dfTeams= pd.read_excel('https://raw.githubusercontent.com/wtitze/3E/main/Teams.xlsx')
dfTeams
# Out:
#               Name      Discipline                         NOC  Event
# 0          Belgium  3x3 Basketball                     Belgium    Men
# 1            China  3x3 Basketball  People's Republic of China    Men
# 2            China  3x3 Basketball  People's Republic of China  Women
# 3           France  3x3 Basketball                      France  Women
# 4            Italy  3x3 Basketball                       Italy  Women
# ..             ...             ...                         ...    ...
# 738   South Africa      Water Polo                South Africa  Women
# 739          Spain      Water Polo                       Spain    Men
# 740          Spain      Water Polo                       Spain  Women
# 741  United States      Water Polo    United States of America    Men
# 742  United States      Water Polo    United States of America  Women
#
# [743 rows x 4 columns]

# %% [markdown]
# quante sono le scuadre italiane

# %%
dfTeams[dfTeams.Name == 'Italy'][["Discipline"]].count()
# Out:
# Discipline    34
# dtype: int64

# %% [markdown]
# quante sono le scuadre tedesco

# %%
dfTeams[dfTeams.Name == 'Germany'][["Discipline"]].count()
# Out:
# Discipline    32
# dtype: int64

# %% [markdown]
# prendere un gruppo di informazioni e fare calcoli.
# o prendere un gruppo9 di informazione specifico.

# %%
dfTeams.groupby("Name").count()[["NOC"]]      #'groupby' serve per prendere delle informazioni e fare qualsiasi cosa in gruppo
# Out:
#                               NOC
# Name
# ACHANTA Kamal / BATRA Manika    1
# ASSAR Omar / MESHREF Dina       1
# Abicha/Elgraoui                 1
# Agatha/Duda                     1
# Alison/Alvaro Filho             1
# ...                           ...
# WONG Chun Ting / DOO Hoi Kem    1
# Wang/X.Y.Xia                    1
# XU Xin / LIU Shiwen             1
# Xue/Wang X.X.                   1
# Zambia                          1
#
# [146 rows x 1 columns]

# %%
dfgrop=dfTeams.groupby("Name").count()[["NOC"]]
dfgrop[dfgrop.NOC>10]
# Out:
#                    NOC
# Name
# Australia           32
# Brazil              21
# Canada              27
# China               30
# Egypt               11
# France              32
# Germany             32
# Great Britain       28
# Hungary             13
# Italy               34
# Japan               45
# Netherlands         24
# New Zealand         13
# Poland              19
# ROC                 31
# Republic of Korea   17
# South Africa        12
# Spain               18
# United States       43

# %% [markdown]
# inserire l'indice

# %%
dfgrop1=dfTeams.groupby("Name").count().reset_index()[["NOC"]]
dfgrop1
# Out:
#      NOC
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ..   ...
# 141    1
# 142    1
# 143    1
# 144    1
# 145    1
#
# [146 rows x 1 columns]

# %% [markdown]
# # ***/-FUNZIONI DI AGGREGAZIONE(max,min,sum,count)-/***

# %%
dfgrop1=dfTeams.groupby("Name").count().reset_index()  #.reset_index()
dfgrop1
# Out:
#                              Name  Discipline  NOC  Event
# 0    ACHANTA Kamal / BATRA Manika           1    1      1
# 1       ASSAR Omar / MESHREF Dina           1    1      1
# 2                 Abicha/Elgraoui           1    1      1
# 3                     Agatha/Duda           1    1      1
# 4             Alison/Alvaro Filho           1    1      1
# ..                            ...         ...  ...    ...
# 141  WONG Chun Ting / DOO Hoi Kem           1    1      1
# 142                  Wang/X.Y.Xia           1    1      1
# 143           XU Xin / LIU Shiwen           1    1      1
# 144                 Xue/Wang X.X.           1    1      1
# 145                        Zambia           1    1      1
#
# [146 rows x 4 columns]

# %% [markdown]
# #esercizi su ***groupby***

# %%
dfMain= pd.read_csv('https://raw.githubusercontent.com/wtitze/3E/main/2010.csv',sep=";")
dfMain
# Out:
#                                      Title    Year  \
# 0                               127 Hours   2010.0
# 1                             3 Backyards   2010.0
# 2                                       3   2010.0
# 3               8: The Mormon Proposition   2010.0
# 4     A Turtle's Tale: Sammy's Adventures   2010.0
# ...                                    ...     ...
# 1599              War & Peace                  NaN
# 1600                    Wings                  NaN
# 1601               Wolf Creek                  NaN
# 1602        Wuthering Heights                  NaN
# 1603  Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                          Genres  Language    Country  \
# 0            Adventure|Biography|Drama|Thriller   English        USA
# 1                                         Drama   English        USA
# 2                          Comedy|Drama|Romance    German    Germany
# 3                                   Documentary   English        USA
# ...

# %% [markdown]
# **1. il numero di film per ogni lingua. Ordinare in ordine decrescente sul numero di film**

# %%
dfMain.groupby("Language").count().sort_values(by=["Title"],ascending=False)[["Title"]]
# Out:
#             Title
# Language
# English      1481
# French         24
# Spanish        16
# Hindi          11
# Mandarin        9
# Japanese        6
# Russian         6
# Polish          4
# Portuguese      3
# Italian         3
# Hebrew          3
# German          3
# Chinese         3
# Cantonese       3
# Norwegian       2
# Swedish         2
# Persian         2
# Arabic          2
# Indonesian      2
# Icelandic       2
# None            1
# Panjabi         1
# Bosnian         1
# Korean          1
# Kannada         1
# Romanian        1
# Slovenian       1
# Swahili         1
# Danish          1
# Tamil           1
# Telugu          1
# Urdu            1

# %%
dfMain.groupby("Country").count()[["Title"]]
# Out:
#                       Title
# Country
# Australia                18
# Bahamas                   1
# Belgium                   4
# Brazil                    3
# Bulgaria                  1
# Cambodia                  1
# Canada                   44
# Chile                     1
# China                    15
# Czech Republic            1
# Denmark                   4
# Dominican Republic        1
# Egypt                     1
# Finland                   1
# France                   54
# Georgia                   1
# Germany                  12
# Greece                    1
# Hong Kong                 3
# Hungary                   1
# Iceland                   2
# India                    16
# Indonesia                 1
# Iran                      1
# Ireland                   4
# Israel                    2
# Italy                     6
# Japan                     8
# Kenya                     1
# Kyrgyzstan                1
# Mexico                   12
# New Zealand               6
# ...

# %% [markdown]
# # ***3. il budget totale che ogni nazione ha investito nei film. Ordinare in ordine decrescente base al budget totale***

# %%
dfbudget=dfMain.groupby("Country").sum().sort_values(by=["Budget"],ascending=False)[["Budget"]]
dfbudget
# Out:
#                             Budget
# Country
# USA                   4.592011e+10
# UK                    3.618860e+09
# France                9.207000e+08
# India                 7.931937e+08
# Australia             7.515000e+08
# China                 4.900050e+08
# Germany               3.901100e+08
# Canada                3.172000e+08
# New Zealand           3.028500e+08
# Japan                 1.575000e+08
# Spain                 1.500000e+08
# Russia                1.190000e+08
# Norway                9.080000e+07
# South Africa          8.400000e+07
# Hong Kong             8.160000e+07
# South Korea           7.522000e+07
# Mexico                6.781878e+07
# Czech Republic        5.000000e+07
# Belgium               4.900000e+07
# Ireland               4.200000e+07
# Italy                 3.880000e+07
# Switzerland           3.000000e+07
# Chile                 2.600000e+07
# Georgia               2.000000e+07
# Hungary               2.000000e+07
# ...

# %% [markdown]
# # ***4. la nazione che ha investito il budget più alto***

# %%
dfbudget[dfbudget["Budget"]==dfbudget["Budget"].max()]
# Out:
#                Budget
# Country
# USA      4.592011e+10

# %% [markdown]
# # ***5. il budget medio che ogni nazione ha investito nei film. Ordinare in ordine decrescente base al budget medio***

# %%
dfMain.groupby('Country')[["Budget"]].mean()
# Out:
#                             Budget
# Country
# Australia             5.010000e+07
# Bahamas               5.000000e+06
# Belgium               2.450000e+07
# Brazil                3.666667e+06
# Bulgaria              7.000000e+06
# Cambodia                       NaN
# Canada                9.062857e+06
# Chile                 2.600000e+07
# China                 4.900050e+07
# Czech Republic        5.000000e+07
# Denmark               4.250000e+06
# Dominican Republic    5.000000e+05
# Egypt                 1.500000e+06
# Finland               3.850000e+06
# France                2.192143e+07
# Georgia               2.000000e+07
# Germany               3.901100e+07
# Greece                1.800000e+07
# Hong Kong             2.720000e+07
# Hungary               2.000000e+07
# Iceland               1.000000e+07
# India                 9.914922e+07
# Indonesia             1.100000e+06
# Iran                  5.000000e+05
# Ireland               1.400000e+07
# ...

# %% [markdown]
# # ***6. le nazioni che hanno investito, in media, un budget più basso rispetto alla media complessiva dei budget delle nazioni***

# %%
  mediaFilm=dfMain.Budget.mean()
  mediaFilm
# Out:
# 40563243.28888889

# %%
mediapernazione=dfMain.groupby('Country')[["Budget"]].mean()
mediapernazione
# Out:
#                             Budget
# Country
# Australia             5.010000e+07
# Bahamas               5.000000e+06
# Belgium               2.450000e+07
# Brazil                3.666667e+06
# Bulgaria              7.000000e+06
# Cambodia                       NaN
# Canada                9.062857e+06
# Chile                 2.600000e+07
# China                 4.900050e+07
# Czech Republic        5.000000e+07
# Denmark               4.250000e+06
# Dominican Republic    5.000000e+05
# Egypt                 1.500000e+06
# Finland               3.850000e+06
# France                2.192143e+07
# Georgia               2.000000e+07
# Germany               3.901100e+07
# Greece                1.800000e+07
# Hong Kong             2.720000e+07
# Hungary               2.000000e+07
# Iceland               1.000000e+07
# India                 9.914922e+07
# Indonesia             1.100000e+06
# Iran                  5.000000e+05
# Ireland               1.400000e+07
# ...

# %%
mediapernazione[mediapernazione.Budget<mediaFilm]  #visualizza tutto quello che è inferiore alla media
# Out:
#                             Budget
# Country
# Bahamas               5.000000e+06
# Belgium               2.450000e+07
# Brazil                3.666667e+06
# Bulgaria              7.000000e+06
# Canada                9.062857e+06
# Chile                 2.600000e+07
# Denmark               4.250000e+06
# Dominican Republic    5.000000e+05
# Egypt                 1.500000e+06
# Finland               3.850000e+06
# France                2.192143e+07
# Georgia               2.000000e+07
# Germany               3.901100e+07
# Greece                1.800000e+07
# Hong Kong             2.720000e+07
# Hungary               2.000000e+07
# Iceland               1.000000e+07
# Indonesia             1.100000e+06
# Iran                  5.000000e+05
# Ireland               1.400000e+07
# Israel                4.500000e+05
# Italy                 9.700000e+06
# Japan                 3.150000e+07
# Kenya                 1.500000e+04
# Kyrgyzstan            1.400000e+06
# ...

# %% [markdown]
# # ***9. il numero di film per ogni genere***

# %%
dfbudge3=dfMain.groupby("Genres").count()[["Title"]]
dfbudge3
# Out:
#                                                     Title
# Genres
# Action                                                  6
# Action|Adventure                                        3
# Action|Adventure|Animation|Comedy|Drama|Family|...      1
# Action|Adventure|Animation|Comedy|Drama|Family|...      1
# Action|Adventure|Animation|Comedy|Family                3
# ...                                                   ...
# Romance|Sci-Fi|Thriller                                 1
# Sci-Fi                                                  1
# Sci-Fi|Thriller                                         4
# Thriller                                               11
# Western                                                 2
#
# [452 rows x 1 columns]
