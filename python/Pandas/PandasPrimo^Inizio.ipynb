# %% [markdown]
# ##Pandas

# %% [markdown]
# Per caricare i dati da un file in un databframe con Pandas è necessario prima caricare nel proprio Drive i file che si intendono utilizzare.

# %% [markdown]
# Poi bisogna far sì che il notebook di COlab abbia accesso al Drive tramite il metodo mount() di drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# %% [markdown]
# A questo punto basta utilizzare il metodo read_csv() (o altro a seconda del file) per leggere il file:

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/winemag-data-130k-v2.csv', index_col=0) #index_col=0 serviva precedentemente per indicizare la posizione su exel
df.head() #si vedono le prime 5 righe
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
pd.DataFrame({'Apples': [30], 'Bananas': [21]})
# Out:
#    Apples  Bananas
# 0      30       21

# %% [markdown]
# si vogliono memorizare i voti di alcuni studenti in alcune materie .
# lo studente neri ha preso 4 in informatica ,5 in sistemi e 2 in tecnoloria.
# òo studente bernasconi ha preso 6 in informatica 2 in sistemi 8 in tecnologia
# .caricare i dati in un dataframe chiamato voti

# %%
voti=pd.DataFrame({'sistemi': [2,2], 
'informatica': [6,4]},
'tecnologia': [8,2]}
index=['bernasconi', 'Neri'])

# %%
df.country        #prende solo una colonna
#versione alternativa
df["country"]

# %%
df.country[90]

# %%
df.country[0:90]  #visualizare una posizione

# %%
#versione alterbnativa
df.country[5:90]

# %%
df.tail() #prende gli ultimi 5

# %% [markdown]
# iloc serve per trovare un indice

# %%
df.iloc[0]   #da i valori di una colonna laterale[------]

# %%
df.iloc[10:15,0]  #da le informazione della prima colonna[|]

# %%
df.iloc[10:15,0:5] #posso prendere si tot valori per[|] che per[--------]        "le posizioni sono corrispondenti"

# %%
df.country == 'Italy' #per fare le ricerche     #serve per vedere se è presente con un true o un false

# %%
df[df.country == 'Italy']  #per fare le ricerche              #visualiza tutto quello che ha italy

# %%
df[(df["country"]=="Italy")&(df["price"]>200)]   #& è uguale a and(la funzione)

# %%
df[(df.country == 'Italy') & (df.points >= 50)]

# %%
df[(df["country"]=="Italy")|(df["country"]=="France")]  #| è uguale ad or  # fa vedere piu ricerche contemporaneamente

# %%
df[df.country.isin(['Italy', 'France'])]     #uguale ha quello precedente
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 7       France  This dry and restrained wine offers spice in p...
# 9       France  This has great depth of flavor with its fresh ...
# 11      France  This is a dry wine, very spicy, with a tight, ...
# ...        ...                                                ...
# 129964  France  Initially quite muted, this wine slowly develo...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %% [markdown]
# NaN= Not a Namber

# %%
df[df.price.notnull()]  # fa vedere dove c'e un valore numerico
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# ...

# %%
df[df.price.isnull()]  # fa vedere dove non c'è un valore numerico
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 13         Italy  This is dominated by oak and oak-driven aromas...
# 30        France  Red cherry fruit comes laced with light tannin...
# 31         Italy  Merlot and Nero d'Avola form the base for this...
# 32         Italy  Part of the extended Calanìca series, this Gri...
# ...          ...                                                ...
# 129844     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129860  Portugal  This rich wine has a firm structure as well as...
# 129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964    France  Initially quite muted, this wine slowly develo...
#
#                          designation  points  price           province  \
# 0                       Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
df[:2]
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %% [markdown]
# # 2°parte

# %%
df["price"]
# Out:
# 0          NaN
# 1         15.0
# 2         14.0
# 3         13.0
# 4         65.0
#           ...
# 129966    28.0
# 129967    75.0
# 129968    30.0
# 129969    32.0
# 129970    21.0
# Name: price, Length: 129971, dtype: float64

# %%
min(df["price"])  #considera anche i valori nulli
# Out:
# nan

# %%
df["price"].min()  #trova il valore minimo (numerico)
# Out:
# 4.0

# %%
df["price"].max()  #per trovare il valore massimo
# Out:
# 3300.0

# %% [markdown]
# # -----------Non Deltutto separato-----------

# %%
#trova il nome di quello con il valore più alto
df[df["price"]==df["price"].max()]
# Out:
#       country                                        description designation  \
# 80290  France  This ripe wine shows plenty of blackberry frui...         NaN
#
#        points   price  province region_1 region_2 taster_name  \
# 80290      88  3300.0  Bordeaux    Médoc      NaN  Roger Voss
#
#       taster_twitter_handle                                 title  \
# 80290            @vossroger  Château les Ormes Sorbet 2013  Médoc
#
#                         variety                    winery
# 80290  Bordeaux-style Red Blend  Château les Ormes Sorbet

# %%
#versione alternativa
df[df["price"]==df["price"].max()]["title"]  #prende semplicemente il nome del vino con il costo più alto
# Out:
# 80290    Château les Ormes Sorbet 2013  Médoc
# Name: title, dtype: object

# %% [markdown]
# # ----------------------------------------------------------------------------------------

# %%
df[df["price"]==df["price"].min()]["title"]   #visualiza tutti i valori più piccoli
#in questo caso i vini anno tutti lo stesso prezzo

# %%
df[df["price"]==df["price"].min()][["title","price"]]  #per far vedere piu colonne contemporaneaomente si mettono due parentesi quadre una dentro l'altrea "[[]]"

# %%
df["points"].sum()
# Out:
# 11495563

# %%
df["price"].mean()
# Out:
# 35.363389129985535

# %% [markdown]
# ***ESERCIZI***

# %%
#nome della casa produttrice che costano più della media
df[df["price"]>df["price"].mean()][["winery","price"]]
# Out:
#                      winery  price
# 4              Sweet Cheeks   65.0
# 25      Castello di Amorosa   69.0
# 33                  Envolve   50.0
# 35                    Erath   50.0
# 45                   Tarara   40.0
# ...                     ...    ...
# 129955            Dog Point   40.0
# 129959    Cave de Turckheim   57.0
# 129960  Caves Transmontanas   48.0
# 129962             Cusumano   40.0
# 129967             Citation   75.0
#
# [39743 rows x 2 columns]

# %% [markdown]
# # -----------Non Deltutto separato-----------

# %%
#versione python
len(df[df.country == 'US'])   #il numero di vini americani
# Out:
# 54504

# %%
#versione pandas
df[df.country == 'US'].count()    #non conta i valori NaN
# Out:
# country                  54504
# description              54504
# designation              36908
# points                   54504
# price                    54265
# province                 54504
# region_1                 54226
# region_2                 50511
# taster_name              37730
# taster_twitter_handle    34741
# title                    54504
# variety                  54504
# winery                   54504
# dtype: int64

# %%
#visualizza semplicemente quello che cecavamo cioè "country"
df[df.country == 'US']["country"].count()
# Out:
# 54504

# %% [markdown]
# ***---------------------------------***
